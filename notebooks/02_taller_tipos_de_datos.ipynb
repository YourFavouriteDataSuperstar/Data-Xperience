# %% [markdown]
# <a href="https://colab.research.google.com/github/YourFavouriteDataSuperstar/Data-Xperience/blob/main/notebooks/02_taller_tipos_de_datos.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <div style="background:#0B4F6C;border-radius:12px;padding:32px 28px;margin:14px 0;">
#   <div style="color:#8FD3E8;font-size:13px;letter-spacing:5px;font-weight:700;">DATAXPERIENCE</div>
#   <div style="color:#FFFFFF;font-size:38px;font-weight:800;line-height:1.15;margin-top:8px;">Taller de Tipos de Datos en Python</div>
#   <div style="color:#C9E7F2;font-size:16px;margin-top:12px;">36 ejercicios de aplicacion + 1 reto integrador. Sin soluciones. Sin pistas.</div>
#   <div style="margin-top:18px;">
#     <span style="background:#FFFFFF;color:#0B4F6C;padding:5px 14px;border-radius:14px;font-size:12px;font-weight:700;">NIVEL: INTERMEDIO</span>
#     <span style="background:#8FD3E8;color:#083A50;padding:5px 14px;border-radius:14px;font-size:12px;font-weight:700;margin-left:6px;">DURACION SUGERIDA: 3 SESIONES</span>
#     <span style="background:#F2C14E;color:#4A3708;padding:5px 14px;border-radius:14px;font-size:12px;font-weight:700;margin-left:6px;">TRABAJO INDIVIDUAL</span>
#   </div>
# </div>

# %% [markdown]
# ## Como funciona este taller
#
# Este taller **no es un tutorial**. No vas a encontrar explicaciones nuevas, ni ejemplos resueltos, ni pistas sobre que funcion o metodo usar. Cada ejercicio plantea una situacion y un resultado esperado: la ruta para llegar ahi es la parte que te corresponde a ti.
#
# <div style="background:#E7EAEE;border-radius:8px;padding:16px 20px;margin:14px 0;">
#   <table style="width:100%;border-collapse:collapse;color:#242B33;font-size:14px;">
#     <tr>
#       <td style="padding:8px 10px;font-weight:700;width:190px;vertical-align:top;">Material de apoyo</td>
#       <td style="padding:8px 10px;">El notebook de la clase (<code>01_tipos_de_datos_python.ipynb</code>) y la documentacion oficial de Python.</td>
#     </tr>
#     <tr>
#       <td style="padding:8px 10px;font-weight:700;vertical-align:top;">Regla de oro</td>
#       <td style="padding:8px 10px;">Antes de escribir codigo, escribe en un comentario que crees que va a pasar. Ejecuta despues. Si tu prediccion falla, ahi esta el aprendizaje.</td>
#     </tr>
#     <tr>
#       <td style="padding:8px 10px;font-weight:700;vertical-align:top;">Prohibido</td>
#       <td style="padding:8px 10px;">Librerias externas (pandas, numpy, collections, re, datetime) salvo que el enunciado lo autorice explicitamente. Todo se resuelve con Python puro.</td>
#     </tr>
#     <tr>
#       <td style="padding:8px 10px;font-weight:700;vertical-align:top;">Cada entrega incluye</td>
#       <td style="padding:8px 10px;">El codigo funcionando, las impresiones que pide el enunciado y una respuesta escrita a la pregunta de cierre (como comentario o celda de texto).</td>
#     </tr>
#     <tr>
#       <td style="padding:8px 10px;font-weight:700;vertical-align:top;">Etiquetas</td>
#       <td style="padding:8px 10px;"><b>APLICACION</b>: resuelve un caso. <b>ANALISIS</b>: ademas debes explicar por que Python se comporta asi. <b>TRAMPA</b>: hay un comportamiento contraintuitivo escondido; encuentralo.</td>
#     </tr>
#   </table>
# </div>
#
# > Si un ejercicio te toma mas de 25 minutos sin avanzar, deja constancia de lo que intentaste y sigue con el siguiente. El bloqueo documentado tambien se califica.
#
# ---

# %% [markdown]
# ## Mapa del taller
#
# <div style="display:block;">
# <table style="width:100%;border-collapse:collapse;font-size:14px;">
#   <tr style="background:#0B4F6C;color:#FFFFFF;">
#     <th style="padding:10px;text-align:left;">Bloque</th>
#     <th style="padding:10px;text-align:left;">Tipo de dato</th>
#     <th style="padding:10px;text-align:left;">Eje de trabajo</th>
#     <th style="padding:10px;text-align:center;">Ejercicios</th>
#   </tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">1</td><td style="padding:9px;"><code>int</code></td><td style="padding:9px;">Aritmetica entera, division exacta y residuos</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;">2</td><td style="padding:9px;"><code>float</code></td><td style="padding:9px;">Precision, redondeo y valores especiales</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">3</td><td style="padding:9px;"><code>str</code></td><td style="padding:9px;">Limpieza, parseo y construccion de texto</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;">4</td><td style="padding:9px;"><code>bool</code></td><td style="padding:9px;">Logica, veracidad y evaluacion perezosa</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">5</td><td style="padding:9px;"><code>list</code></td><td style="padding:9px;">Mutabilidad, orden y estructuras anidadas</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;">6</td><td style="padding:9px;"><code>tuple</code></td><td style="padding:9px;">Inmutabilidad, desempaquetado y hashabilidad</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">7</td><td style="padding:9px;"><code>dict</code></td><td style="padding:9px;">Indexacion por clave, anidamiento y agregacion</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;">8</td><td style="padding:9px;"><code>set</code></td><td style="padding:9px;">Unicidad, pertenencia y algebra de conjuntos</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">9</td><td style="padding:9px;">conversion</td><td style="padding:9px;">Casting seguro entre tipos y estructuras</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="background:#0B4F6C;color:#FFFFFF;"><td style="padding:9px;">R</td><td style="padding:9px;">Todos</td><td style="padding:9px;">Reto integrador de cierre</td><td style="padding:9px;text-align:center;">1</td></tr>
# </table>
# </div>
#
# ---

# %% [markdown]
# <div style="background:#D6EEF6;border-left:10px solid #0B4F6C;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B4F6C;">BLOQUE 1</div>
#   <div style="font-size:26px;font-weight:800;color:#083A50;margin-top:2px;">Numeros enteros: <code style='color:#083A50;'>int</code></div>
#   <div style="font-size:14px;color:#083A50;margin-top:6px;">Cuatro casos donde perder la parte decimal no es un error: es el requisito.</div>
# </div>

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.1</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Logistica de una jornada de vacunacion</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Una brigada de salud recibe <b>4.187</b> dosis y debe empacarlas en neveras portatiles de <b>36</b> dosis cada una. Solo se despachan neveras <b>completas</b>; lo que sobra vuelve a la bodega central. Cada nevera completa requiere 2 tecnicos, y la bodega cobra una tarifa de almacenamiento de $850 por dosis devuelta.<br><br>
# Tu programa debe reportar: cuantas neveras salen a ruta, cuantos tecnicos se necesitan, cuantas dosis regresan a bodega y cuanto cuesta esa devolucion. <b>Los cuatro resultados deben ser de tipo <code>int</code>; verificalo imprimiendo el tipo de cada uno.</b><br><br>
# <b>Cierre:</b> si manana llegan 4.188 dosis en lugar de 4.187, cual de los cuatro numeros cambia y cual no. Responde antes de ejecutar y luego comprueba.
# </div>
# </div>

# %%
# EJERCICIO 1.1
dosis_recibidas = 4187
dosis_por_nevera = 36
tecnicos_por_nevera = 2
tarifa_devolucion = 850

# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.2</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Descomposicion de un tiempo de proceso</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Un proceso de carga de datos tardo <b>1.234.567 segundos</b> acumulados durante el semestre. El area de operaciones necesita ese numero expresado en <b>semanas, dias, horas, minutos y segundos</b>, de forma que ninguna unidad supere su limite natural (los segundos no pueden dar 90, los minutos no pueden dar 75, y asi).<br><br>
# Restricciones: <b>no puedes usar ninguna libreria</b> (nada de <code>datetime</code>), <b>no puedes usar division decimal</b> en ningun punto, y todas las variables intermedias deben ser enteras. Al final imprime una sola linea con el formato <code>2 semanas, 0 dias, 6 horas, 56 minutos, 7 segundos</code> (los numeros del ejemplo son inventados).<br><br>
# <b>Cierre:</b> demuestra con codigo que tu descomposicion es correcta, reconstruyendo el total original a partir de las cinco piezas.
# </div>
# </div>

# %%
# EJERCICIO 1.2
total_segundos = 1234567

# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.3</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Digito verificador sin tocar texto</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# El area de matriculas valida los codigos de estudiante de <b>8 digitos</b> con esta regla: se toma cada digito, se multiplica por su posicion contando desde la derecha empezando en 1, se suman todos los productos y el codigo es valido si esa suma es divisible por 7.<br><br>
# Implementa la validacion para los codigos <code>20260417</code>, <code>19998842</code> y <code>70000003</code>. <b>Restriccion dura: en ningun momento puedes convertir el numero a texto</b> ni usar indices de cadena. Solo aritmetica entera.<br><br>
# Imprime, para cada codigo, la suma calculada y si es valido o no.<br><br>
# <b>Cierre:</b> explica que operacion te permite "ver" el ultimo digito de un numero y cual te permite "borrarlo". Sin ellas dos este ejercicio no sale.
# </div>
# </div>

# %%
# EJERCICIO 1.3
codigos = [20260417, 19998842, 70000003]

# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.4</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Dinero en centavos</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Un sistema de facturacion guarda todos los montos como <b>enteros en centavos</b> (el precio $19.999,90 se almacena como <code>1999990</code>) precisamente para evitar los errores de los decimales. Recibes tres precios en centavos: <code>1999990</code>, <code>4500</code> y <code>333333</code>, con cantidades <code>3</code>, <code>7</code> y <code>2</code>.<br><br>
# Calcula el subtotal, el IVA del 19% y el total, <b>todo en centavos y todo entero</b>. Cuando el IVA no de un numero exacto de centavos, la regla del negocio es redondear <b>hacia arriba</b> al centavo siguiente (el sistema nunca cobra de menos). Al final, y solo al final, imprime los tres valores formateados como pesos con dos decimales.<br><br>
# <b>Cierre:</b> calcula tambien el IVA redondeando hacia abajo. Cuanto dinero al mes representa la diferencia si el negocio factura 12.000 pedidos como este.
# </div>
# </div>

# %%
# EJERCICIO 1.4
precios_centavos = [1999990, 4500, 333333]
cantidades = [3, 7, 2]
porcentaje_iva = 19

# Tu codigo:

# %% [markdown]
# <div style="background:#DDF3E4;border-left:10px solid #1B7A4B;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#1B7A4B;">BLOQUE 2</div>
#   <div style="font-size:26px;font-weight:800;color:#125634;margin-top:2px;">Numeros decimales: <code style='color:#125634;'>float</code></div>
#   <div style="font-size:14px;color:#125634;margin-top:6px;">Donde el computador no piensa como la calculadora del colegio.</div>
# </div>

# %% [markdown]
# <div style="background:#DDF3E4;border:1px solid #1B7A4B;border-left:6px solid #1B7A4B;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#1B7A4B;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 2.1</span>
#   <span style="border:1px solid #1B7A4B;color:#125634;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#125634;margin:10px 0 6px 0;">La suma que no cierra</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# El area contable reporta que su script "no cuadra por centavos". Reproduce el fenomeno: suma <code>0.1</code> diez veces usando un acumulador y compara el resultado contra <code>1.0</code> con el operador de igualdad. Haz lo mismo comparando <code>0.1 + 0.2</code> contra <code>0.3</code>.<br><br>
# Luego: imprime la diferencia exacta entre lo obtenido y lo esperado con <b>20 decimales</b>, y disena un criterio de comparacion propio que si considere iguales esos pares de valores, expresado como una condicion que devuelva <code>True</code>.<br><br>
# <b>Cierre:</b> tu criterio depende de un numero que tu elegiste. Justifica ese numero: por que no mas grande, por que no mas pequeno. Que pasaria con tu criterio si los montos fueran de miles de millones en lugar de decimas.
# </div>
# </div>

# %%
# EJERCICIO 2.1
# Tu codigo:

# %% [markdown]
# <div style="background:#DDF3E4;border:1px solid #1B7A4B;border-left:6px solid #1B7A4B;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#1B7A4B;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 2.2</span>
#   <span style="border:1px solid #1B7A4B;color:#125634;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">TRAMPA</span>
#   <div style="font-size:19px;font-weight:700;color:#125634;margin:10px 0 6px 0;">Nota definitiva con pesos y politica de aproximacion</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Un curso califica asi: talleres 25%, parcial 30%, proyecto 35%, participacion 10%. Las notas de cinco estudiantes estan en la celda. La nota definitiva se reporta con <b>un decimal</b>, y la politica institucional es que a partir de <b>3,0</b> el estudiante aprueba.<br><br>
# Calcula la definitiva de cada estudiante y determina quien aprueba. <b>Atencion al caso limite:</b> hay al menos un estudiante cuya definitiva antes de redondear queda muy cerca de 2,95. Reporta explicitamente que decidio tu codigo para ese caso y cual es la definitiva sin redondear.<br><br>
# <b>Cierre:</b> un estudiante reclama que redondeando manualmente le da 3,0 y el sistema le puso 2,9. Con evidencia de tu propio codigo, explica quien tiene la razon y por que ocurre.
# </div>
# </div>

# %%
# EJERCICIO 2.2
# nombre: [talleres, parcial, proyecto, participacion]
notas = {
    "Valentina": [3.8, 2.6, 3.1, 4.5],
    "Andres":    [2.9, 2.7, 3.05, 3.4],
    "Sofia":     [4.6, 4.9, 4.75, 5.0],
    "Mateo":     [2.4, 2.9, 3.2, 2.8],
    "Camilo":    [3.0, 3.0, 2.9, 3.0],
}
pesos = [0.25, 0.30, 0.35, 0.10]

# Tu codigo:

# %% [markdown]
# <div style="background:#DDF3E4;border:1px solid #1B7A4B;border-left:6px solid #1B7A4B;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#1B7A4B;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 2.3</span>
#   <span style="border:1px solid #1B7A4B;color:#125634;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#125634;margin:10px 0 6px 0;">Simulacion de credito</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Un estudiante pide un credito educativo de <b>$8.400.000</b> a una tasa del <b>1,3% mensual</b> durante <b>24 meses</b>. Compara dos escenarios: interes simple (la tasa se aplica siempre sobre el capital inicial) e interes compuesto (la tasa se aplica sobre el saldo acumulado del mes anterior).<br><br>
# Genera una tabla impresa mes a mes con: numero de mes, saldo con interes simple y saldo con interes compuesto, alineados en columnas y con separador de miles y dos decimales. Al final reporta la diferencia total entre ambos escenarios y a partir de que mes esa diferencia supera <b>$500.000</b>.<br><br>
# <b>Cierre:</b> si la tasa fuera del 0,1% mensual, en cual mes se cruzaria ese umbral. Responde con el codigo, cambiando un solo valor.
# </div>
# </div>

# %%
# EJERCICIO 2.3
capital = 8400000.0
tasa_mensual = 0.013
meses = 24

# Tu codigo:

# %% [markdown]
# <div style="background:#DDF3E4;border:1px solid #1B7A4B;border-left:6px solid #1B7A4B;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#1B7A4B;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 2.4</span>
#   <span style="border:1px solid #1B7A4B;color:#125634;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">TRAMPA</span>
#   <div style="font-size:19px;font-weight:700;color:#125634;margin:10px 0 6px 0;">Sensores con lecturas dañadas</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Un sensor de temperatura envio las lecturas de la celda. Entre ellas hay dos valores que no son numeros normales: <code>float('nan')</code> (dato perdido) y <code>float('inf')</code> (desbordamiento del sensor).<br><br>
# Tu programa debe: contar cuantas lecturas son utilizables, calcular el promedio solo con esas, y normalizar cada lectura utilizable a una escala de 0 a 100 respecto al minimo y maximo validos. Las lecturas no utilizables deben quedar reportadas aparte, indicando su posicion en la lista original.<br><br>
# <b>Cierre obligatorio:</b> evalua e imprime el resultado de <code>nan == nan</code>. Explica que consecuencia tiene ese resultado para la forma en que detectaste los datos perdidos, y por que un filtro basado en igualdad no habria servido.
# </div>
# </div>

# %%
# EJERCICIO 2.4
lecturas = [21.5, 22.1, float('nan'), 23.8, 19.4, float('inf'), 20.0, 24.6, 18.9]

# Tu codigo:

# %% [markdown]
# <div style="background:#EAE2F8;border-left:10px solid #5B3A96;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#5B3A96;">BLOQUE 3</div>
#   <div style="font-size:26px;font-weight:800;color:#3F2769;margin-top:2px;">Cadenas de texto: <code style='color:#3F2769;'>str</code></div>
#   <div style="font-size:14px;color:#3F2769;margin-top:6px;">El 80% del trabajo real con datos empieza con texto sucio.</div>
# </div>

# %% [markdown]
# <div style="background:#EAE2F8;border:1px solid #5B3A96;border-left:6px solid #5B3A96;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#5B3A96;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 3.1</span>
#   <span style="border:1px solid #5B3A96;color:#3F2769;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#3F2769;margin:10px 0 6px 0;">Normalizacion de un listado de inscritos</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# El listado de la celda viene de un formulario web: espacios sobrantes, mayusculas inconsistentes, separadores irregulares y algun campo vacio.<br><br>
# Produce, para cada registro, una linea con el formato exacto <code>APELLIDO, Nombre (correo en minuscula)</code>. El apellido es la ultima palabra del nombre completo; el nombre es todo lo anterior. Los registros que no tengan correo deben reportarse en un listado separado de "pendientes por contactar", nunca mezclados con los validos.<br><br>
# <b>Cierre:</b> tu solucion sobrevive si aparece un registro con dos apellidos, como "Maria Jose Perez Ossa". Pruebalo agregandolo tu mismo y describe que sale. Si sale mal, no lo arregles: explica exactamente por que la regla del enunciado es insuficiente.
# </div>
# </div>

# %%
# EJERCICIO 3.1
inscritos = [
    "  ana maria RODRIGUEZ  |  Ana.Rodriguez@ejemplo.COM ",
    "JUAN pablo Gomez|juanp@ejemplo.com",
    "  laura Restrepo | ",
    "CARLOS  ANDRES  Zapata  |CZapata@Ejemplo.com  ",
    "Diana Torres|",
]

# Tu codigo:

# %% [markdown]
# <div style="background:#EAE2F8;border:1px solid #5B3A96;border-left:6px solid #5B3A96;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#5B3A96;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 3.2</span>
#   <span style="border:1px solid #5B3A96;color:#3F2769;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#3F2769;margin:10px 0 6px 0;">Lectura de un archivo plano</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# La celda contiene cinco lineas de un archivo de ventas separado por punto y coma, con encabezado incluido. Los campos son fecha, sucursal, producto, unidades y valor unitario.<br><br>
# Sin usar librerias de CSV, construye un reporte impreso que muestre, por sucursal, el total facturado y el numero de unidades vendidas. El reporte debe verse alineado en columnas, con los valores en formato de moneda y el nombre de la sucursal en un ancho fijo, de modo que se lea como una tabla aunque los nombres tengan distinta longitud.<br><br>
# <b>Cierre:</b> el archivo real tiene 400.000 lineas y una de ellas trae el valor unitario vacio. Que hace tu codigo con esa linea. Agregala al ejemplo y observa.
# </div>
# </div>

# %%
# EJERCICIO 3.2
archivo = """fecha;sucursal;producto;unidades;valor_unitario
2026-03-01;Chapinero;teclado;12;89000
2026-03-01;Kennedy;monitor;3;750000
2026-03-02;Chapinero;monitor;5;750000
2026-03-02;Suba;teclado;20;89000
2026-03-03;Kennedy;mouse;15;45000"""

# Tu codigo:

# %% [markdown]
# <div style="background:#EAE2F8;border:1px solid #5B3A96;border-left:6px solid #5B3A96;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#5B3A96;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 3.3</span>
#   <span style="border:1px solid #5B3A96;color:#3F2769;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#3F2769;margin:10px 0 6px 0;">Enmascaramiento de datos personales</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Antes de compartir una base con un proveedor externo, hay que ofuscar los datos sensibles cumpliendo estas reglas:<br>
# <ul style="margin:6px 0 6px 18px;">
# <li>Correo: se conservan los dos primeros caracteres del usuario y el dominio completo; el resto del usuario se reemplaza por asteriscos, uno por cada caracter oculto.</li>
# <li>Documento: se conservan los dos ultimos digitos; el resto se reemplaza por <code>X</code>.</li>
# <li>Telefono: se conservan los tres ultimos digitos y se muestran precedidos de <code>(...)</code>.</li>
# </ul>
# Tu solucion debe funcionar con <b>cualquier longitud</b> de entrada, no solo con los ejemplos dados. Incluye en tus pruebas un correo cuyo usuario tenga solo dos caracteres y describe que produce tu regla en ese caso.<br><br>
# <b>Cierre:</b> una de las tres reglas puede terminar revelando informacion util a un atacante cuando el dato de entrada es muy corto. Cual es y por que.
# </div>
# </div>

# %%
# EJERCICIO 3.3
registros = [
    {"correo": "valentina.ruiz@correo.com", "documento": "1012456789", "telefono": "3009876543"},
    {"correo": "ab@ean.edu.co",             "documento": "79451236",   "telefono": "6013456789"},
    {"correo": "j.p.gomez.torres@mail.org", "documento": "1128745",    "telefono": "3151234567"},
]

# Tu codigo:

# %% [markdown]
# <div style="background:#EAE2F8;border:1px solid #5B3A96;border-left:6px solid #5B3A96;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#5B3A96;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 3.4</span>
#   <span style="border:1px solid #5B3A96;color:#3F2769;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#3F2769;margin:10px 0 6px 0;">Codigos de inventario</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Los codigos de activo de la universidad tienen la forma <code>AA-2026-BOG-0042</code>: dos letras de categoria, ano de cuatro digitos, tres letras de sede y un consecutivo de cuatro digitos con ceros a la izquierda.<br><br>
# Escribe un validador que, para cada codigo de la celda, diga si cumple la estructura y, en caso de no cumplirla, indique <b>cual regla especifica</b> incumple (longitud, posicion de los separadores, tipo de caracteres en cada segmento). Para los codigos validos, genera ademas el <b>codigo siguiente</b> del consecutivo, conservando los ceros a la izquierda y avisando cuando el consecutivo se desborde.<br><br>
# <b>Cierre:</b> cuantos activos por sede y categoria puede numerar este esquema. Que cambiarias en el formato si la universidad proyecta duplicar esa cifra.
# </div>
# </div>

# %%
# EJERCICIO 3.4
codigos = ["AA-2026-BOG-0042", "ZZ-2026-MED-9999", "A-2026-BOG-0001",
           "AA-20X6-BOG-0007", "AA-2026-BOG-42", "BB_2025_CAL_0100"]

# Tu codigo:

# %% [markdown]
# <div style="background:#FDEBD8;border-left:10px solid #B35309;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#B35309;">BLOQUE 4</div>
#   <div style="font-size:26px;font-weight:800;color:#7E3A06;margin-top:2px;">Valores logicos: <code style='color:#7E3A06;'>bool</code></div>
#   <div style="font-size:14px;color:#7E3A06;margin-top:6px;">Toda decision automatica del mundo se reduce a estos dos valores.</div>
# </div>

# %% [markdown]
# <div style="background:#FDEBD8;border:1px solid #B35309;border-left:6px solid #B35309;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#B35309;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.1</span>
#   <span style="border:1px solid #B35309;color:#7E3A06;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#7E3A06;margin:10px 0 6px 0;">Motor de reglas de una beca</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# La beca de sostenimiento se otorga si el estudiante cumple <b>todas</b> estas condiciones: promedio acumulado de 4,0 o mas, al menos 12 creditos inscritos, ninguna materia perdida en el ultimo periodo, y estrato 3 o inferior. Existe una excepcion: quien tenga promedio de 4,6 o mas puede acceder aunque su estrato sea 4, siempre que las demas condiciones se cumplan.<br><br>
# Evalua a los cinco candidatos de la celda. Para cada uno imprime el veredicto y, cuando sea negativo, <b>cuales condiciones especificas fallaron</b> (todas las que fallen, no solo la primera).<br><br>
# <b>Cierre:</b> reescribe la condicion completa en una sola expresion booleana y comparala con tu version por partes. Cual defenderias ante un auditor y por que.
# </div>
# </div>

# %%
# EJERCICIO 4.1
candidatos = [
    {"nombre": "Nicolas", "promedio": 4.2, "creditos": 15, "perdidas": 0, "estrato": 2},
    {"nombre": "Paula",   "promedio": 4.7, "creditos": 14, "perdidas": 0, "estrato": 4},
    {"nombre": "Esteban", "promedio": 4.1, "creditos": 10, "perdidas": 0, "estrato": 1},
    {"nombre": "Juliana", "promedio": 3.9, "creditos": 18, "perdidas": 1, "estrato": 5},
    {"nombre": "Tomas",   "promedio": 4.6, "creditos": 12, "perdidas": 0, "estrato": 4},
]

# Tu codigo:

# %% [markdown]
# <div style="background:#FDEBD8;border:1px solid #B35309;border-left:6px solid #B35309;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#B35309;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.2</span>
#   <span style="border:1px solid #B35309;color:#7E3A06;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">TRAMPA</span>
#   <div style="font-size:19px;font-weight:700;color:#7E3A06;margin:10px 0 6px 0;">Que es verdadero y que no</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Construye una tabla impresa que muestre, para cada valor de la celda, tres columnas: el valor tal cual se ve, su tipo y su veracidad al ser evaluado como condicion.<br><br>
# Antes de ejecutar, <b>escribe tu prediccion para cada valor en un comentario</b>. Al terminar, marca cuales predicciones fallaron.<br><br>
# <b>Cierre:</b> de la lista hay al menos tres valores que representan visualmente "algo vacio, cero o falso" para un ser humano pero que Python considera verdaderos. Identificalos y formula la regla general que los explica.
# </div>
# </div>

# %%
# EJERCICIO 4.2
valores = [0, 1, -1, 0.0, 0.1, "", " ", "0", "False", [], [0], {}, {"a": 0}, set(), (0,), None, float('nan')]

# Tu codigo:

# %% [markdown]
# <div style="background:#FDEBD8;border:1px solid #B35309;border-left:6px solid #B35309;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#B35309;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.3</span>
#   <span style="border:1px solid #B35309;color:#7E3A06;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#7E3A06;margin:10px 0 6px 0;">Auditoria de calidad de un lote</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Un lote de 20 mediciones de control esta en la celda. El lote se aprueba si <b>al menos el 80%</b> de las mediciones esta dentro del rango aceptable (entre 9,5 y 10,5 inclusive) y <b>ninguna</b> medicion se desvia mas de 1,5 unidades del valor objetivo de 10.<br><br>
# Calcula el conteo de mediciones aceptables <b>sin usar un contador incrementado dentro de un condicional</b>: el conteo debe salir directamente de operar con los valores logicos que produce la comparacion. Reporta el porcentaje de cumplimiento, el veredicto del lote y la lista de posiciones que fallaron.<br><br>
# <b>Cierre:</b> explica por que la operacion que usaste para contar funciona. Que tiene el tipo <code>bool</code> que lo hace posible.
# </div>
# </div>

# %%
# EJERCICIO 4.3
mediciones = [9.8, 10.2, 10.5, 9.4, 10.0, 11.6, 9.9, 10.1, 9.5, 10.4,
              10.3, 9.7, 8.2, 10.0, 9.6, 10.5, 9.3, 10.2, 9.9, 10.1]

# Tu codigo:

# %% [markdown]
# <div style="background:#FDEBD8;border:1px solid #B35309;border-left:6px solid #B35309;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#B35309;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.4</span>
#   <span style="border:1px solid #B35309;color:#7E3A06;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">TRAMPA</span>
#   <div style="font-size:19px;font-weight:700;color:#7E3A06;margin:10px 0 6px 0;">Identidad, igualdad y cortocircuito</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Tres experimentos, todos con evidencia impresa:<br>
# <ol style="margin:6px 0 6px 18px;">
# <li>Evalua y explica que devuelven <code>True == 1</code>, <code>True is 1</code>, <code>len({True, 1, 1.0})</code> y <code>{1: "uno", True: "verdadero"}</code>.</li>
# <li>Construye una expresion con <code>and</code> y otra con <code>or</code> en las que el <b>segundo operando nunca llegue a evaluarse</b>, y demuestrelo de forma visible en la salida (no basta con afirmarlo).</li>
# <li>Evalua <code>[] or "sin datos"</code> y <code>0 and 5/0</code>. Reporta el <b>tipo</b> del resultado en cada caso.</li>
# </ol>
# <b>Cierre:</b> los operadores <code>and</code> y <code>or</code> no siempre devuelven un <code>bool</code>. Con base en tus resultados, enuncia que devuelven realmente.
# </div>
# </div>

# %%
# EJERCICIO 4.4
# Tu codigo:

# %% [markdown]
# <div style="background:#E1E8F8;border-left:10px solid #2B4C9B;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#2B4C9B;">BLOQUE 5</div>
#   <div style="font-size:26px;font-weight:800;color:#1B3268;margin-top:2px;">Listas: <code style='color:#1B3268;'>list</code></div>
#   <div style="font-size:14px;color:#1B3268;margin-top:6px;">La estructura mas usada y la que mas errores silenciosos causa.</div>
# </div>

# %% [markdown]
# <div style="background:#E1E8F8;border:1px solid #2B4C9B;border-left:6px solid #2B4C9B;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#2B4C9B;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.1</span>
#   <span style="border:1px solid #2B4C9B;color:#1B3268;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#1B3268;margin:10px 0 6px 0;">El bug de la lista compartida</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Un sistema de matriculas guarda el horario de cada grupo. El programador creo una plantilla de horario vacia y la reutilizo para los tres grupos. Cuando agrego una clase al grupo A, aparecio tambien en B y C.<br><br>
# Reproduce el error: crea la situacion que lo provoca y demuestra con evidencia impresa <b>que</b> las tres variables se comportan como una sola. Luego construye una version corregida y demuestra que ahora son independientes. Finalmente aplica la misma prueba a una lista de listas: comprueba si la correccion que usaste protege tambien el contenido anidado.<br><br>
# <b>Cierre:</b> explica que significa que una variable "apunte" a una lista y por que la asignacion no copia. Que evidencia concreta de tu salida respalda esa explicacion.
# </div>
# </div>

# %%
# EJERCICIO 5.1
plantilla_horario = []
plantilla_semana = [[], [], []]

# Tu codigo:

# %% [markdown]
# <div style="background:#E1E8F8;border:1px solid #2B4C9B;border-left:6px solid #2B4C9B;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#2B4C9B;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.2</span>
#   <span style="border:1px solid #2B4C9B;color:#1B3268;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#1B3268;margin:10px 0 6px 0;">Ranking de ventas sin destruir el original</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# La celda tiene las ventas mensuales de ocho asesores, en el orden en que fueron registradas (ese orden importa: es el orden de antiguedad y no puede perderse).<br><br>
# Produce: el top 3 de mayor venta, el listado completo ordenado de mayor a menor, la posicion en el ranking de un asesor especifico, y el promedio de ventas <b>excluyendo</b> al mejor y al peor. Al terminar, <b>imprime la lista original y demuestra que sigue en el orden de antiguedad</b>.<br><br>
# <b>Cierre:</b> existen dos formas de ordenar en Python y solo una deja intacta la lista original. Muestra ambas en tu celda, con su efecto visible, y di cual usaste para este caso y por que.
# </div>
# </div>

# %%
# EJERCICIO 5.2
asesores = ["Rojas", "Nino", "Cardenas", "Mejia", "Osorio", "Pineda", "Quintero", "Salazar"]
ventas = [12500000, 9800000, 15300000, 7400000, 15300000, 11200000, 6900000, 13750000]

# Tu codigo:

# %% [markdown]
# <div style="background:#E1E8F8;border:1px solid #2B4C9B;border-left:6px solid #2B4C9B;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#2B4C9B;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.3</span>
#   <span style="border:1px solid #2B4C9B;color:#1B3268;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#1B3268;margin:10px 0 6px 0;">Matriz de calificaciones</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# La celda contiene una matriz: cada fila es un estudiante y cada columna es un corte academico. Sin usar librerias, calcula el promedio por estudiante, el promedio por corte, el corte con menor desempeno grupal y el estudiante mas <b>irregular</b> (aquel con la mayor diferencia entre su nota mas alta y su nota mas baja).<br><br>
# Imprime todo como una tabla con encabezados de fila y de columna, y una fila final de promedios por corte.<br><br>
# <b>Cierre:</b> el promedio de los promedios por estudiante coincide con el promedio de los promedios por corte. Verificalo con codigo y explica si eso siempre sera asi o depende de los datos.
# </div>
# </div>

# %%
# EJERCICIO 5.3
estudiantes = ["Acosta", "Bernal", "Cifuentes", "Duarte", "Escobar"]
cortes = ["Corte 1", "Corte 2", "Corte 3"]
calificaciones = [
    [3.5, 4.0, 2.8],
    [4.8, 4.9, 5.0],
    [2.1, 3.9, 4.7],
    [3.0, 3.1, 3.0],
    [4.2, 2.5, 3.8],
]

# Tu codigo:

# %% [markdown]
# <div style="background:#E1E8F8;border:1px solid #2B4C9B;border-left:6px solid #2B4C9B;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#2B4C9B;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.4</span>
#   <span style="border:1px solid #2B4C9B;color:#1B3268;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#1B3268;margin:10px 0 6px 0;">Serie de tiempo por trimestres</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# La celda tiene 12 valores mensuales de trafico web. Sin usar librerias, produce: los cuatro totales trimestrales, la serie en orden inverso, la serie tomando un mes de cada dos empezando por el primero, los tres meses centrales, y una nueva serie donde cada valor sea la variacion respecto al mes anterior (la nueva serie tendra un elemento menos, y debes justificar por que).<br><br>
# Todas las extracciones deben hacerse <b>por rebanado, sin escribir los indices a mano uno por uno</b>.<br><br>
# <b>Cierre:</b> que devuelve un rebanado cuyo rango esta fuera del tamano de la lista. Comparalo con lo que devuelve un indice fuera de rango. Explica por que Python trata distinto los dos casos.
# </div>
# </div>

# %%
# EJERCICIO 5.4
trafico = [14200, 15100, 13980, 17640, 18300, 17020,
           21500, 22800, 19400, 24100, 26700, 31200]

# Tu codigo:

# %% [markdown]
# <div style="background:#F7EED6;border-left:10px solid #7A5C1E;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#7A5C1E;">BLOQUE 6</div>
#   <div style="font-size:26px;font-weight:800;color:#54400F;margin-top:2px;">Tuplas: <code style='color:#54400F;'>tuple</code></div>
#   <div style="font-size:14px;color:#54400F;margin-top:6px;">Cuando el dato no debe cambiar, la estructura misma debe impedirlo.</div>
# </div>

# %% [markdown]
# <div style="background:#F7EED6;border:1px solid #7A5C1E;border-left:6px solid #7A5C1E;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#7A5C1E;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 6.1</span>
#   <span style="border:1px solid #7A5C1E;color:#54400F;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">TRAMPA</span>
#   <div style="font-size:19px;font-weight:700;color:#54400F;margin:10px 0 6px 0;">Una inmutabilidad con letra menuda</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Tienes dos tuplas en la celda. La primera contiene solo numeros; la segunda contiene una lista entre sus elementos.<br><br>
# Intenta modificar un elemento de cada una y captura los errores para que el notebook no se detenga. Luego intenta modificar el <b>contenido de la lista que vive dentro</b> de la segunda tupla y observa. Documenta con impresiones el estado antes y despues.<br><br>
# <b>Cierre:</b> despues de tu experimento, corrige o precisa esta afirmacion: "una tupla es inmutable, por lo tanto sus datos no pueden cambiar". Escribe la version correcta en una sola frase.
# </div>
# </div>

# %%
# EJERCICIO 6.1
punto = (4.6486, -74.0908)
registro = ("sensor-A", [21.5, 22.0, 21.8], "operativo")

# Tu codigo:

# %% [markdown]
# <div style="background:#F7EED6;border:1px solid #7A5C1E;border-left:6px solid #7A5C1E;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#7A5C1E;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 6.2</span>
#   <span style="border:1px solid #7A5C1E;color:#54400F;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#54400F;margin:10px 0 6px 0;">Desempaquetado en una tuberia de datos</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Cada elemento de la celda es un registro de despacho: codigo, ciudad, peso en kilos, y una tupla anidada con las tres ultimas fechas de intento de entrega.<br><br>
# Recorre los registros repartiendo cada campo en variables con nombre propio <b>en una sola instruccion por registro</b> (nada de acceder por indice numerico dentro del cuerpo del ciclo). Del bloque de fechas, separa la primera y conserva el resto agrupado. Imprime una linea legible por despacho.<br><br>
# Adicionalmente: intercambia el valor de dos variables <b>sin usar una variable auxiliar</b> y muestra el antes y el despues.<br><br>
# <b>Cierre:</b> que sucede si un registro trae un campo de mas o de menos. Provocalo y reporta el mensaje de error exacto.
# </div>
# </div>

# %%
# EJERCICIO 6.2
despachos = [
    ("DSP-001", "Bogota", 14.5, ("2026-04-01", "2026-04-03", "2026-04-07")),
    ("DSP-002", "Medellin", 3.2, ("2026-04-02", "2026-04-05", "2026-04-06")),
    ("DSP-003", "Cali", 27.9, ("2026-04-01", "2026-04-02", "2026-04-09")),
]

# Tu codigo:

# %% [markdown]
# <div style="background:#F7EED6;border:1px solid #7A5C1E;border-left:6px solid #7A5C1E;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#7A5C1E;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 6.3</span>
#   <span style="border:1px solid #7A5C1E;color:#54400F;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#54400F;margin:10px 0 6px 0;">Claves compuestas</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Necesitas registrar el numero de matriculados por combinacion de <b>sede, programa y periodo</b>. Un identificador simple no alcanza: la llave es la combinacion de los tres.<br><br>
# Construye una estructura que permita consultar directamente el valor de una combinacion, agrega dos combinaciones nuevas, actualiza una existente y consulta una combinacion inexistente <b>sin que el programa falle</b>. Luego intenta construir la misma estructura usando listas como clave y captura el error.<br><br>
# <b>Cierre:</b> con base en el error obtenido, explica que propiedad debe cumplir un objeto para poder ser clave, y por que las tuplas la cumplen y las listas no. Relacionalo con lo que descubriste en el ejercicio 6.1.
# </div>
# </div>

# %%
# EJERCICIO 6.3
datos_matricula = [
    (("Bogota", "Administracion", "2026-1"), 320),
    (("Bogota", "Ingenieria", "2026-1"), 145),
    (("Medellin", "Administracion", "2026-1"), 98),
]

# Tu codigo:

# %% [markdown]
# <div style="background:#F7EED6;border:1px solid #7A5C1E;border-left:6px solid #7A5C1E;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#7A5C1E;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 6.4</span>
#   <span style="border:1px solid #7A5C1E;color:#54400F;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#54400F;margin:10px 0 6px 0;">Orden natural de las tuplas</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# La celda contiene registros de atletas como tuplas: <code>(tiempo_en_segundos, apellido, edad)</code>.<br><br>
# Ordena la lista tal cual, sin indicar ningun criterio, y observa el resultado. Luego construye deliberadamente un orden que priorice primero la edad y despues el tiempo, reorganizando la informacion, no pidiendo un criterio externo. Finalmente, evalua e interpreta el resultado de comparar directamente dos tuplas con los operadores <code>&lt;</code> y <code>==</code>.<br><br>
# <b>Cierre:</b> deduce y enuncia la regla con la que Python decide si una tupla es "menor" que otra. Prueba tu regla con dos tuplas de <b>distinta longitud</b> y con dos que empiecen igual.
# </div>
# </div>

# %%
# EJERCICIO 6.4
atletas = [
    (612.4, "Ramirez", 24),
    (598.7, "Lopez", 31),
    (612.4, "Alvarez", 19),
    (630.1, "Mendoza", 24),
    (598.7, "Lopez", 28),
]

# Tu codigo:

# %% [markdown]
# <div style="background:#FBE3E6;border-left:10px solid #A32C3A;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#A32C3A;">BLOQUE 7</div>
#   <div style="font-size:26px;font-weight:800;color:#711E28;margin-top:2px;">Diccionarios: <code style='color:#711E28;'>dict</code></div>
#   <div style="font-size:14px;color:#711E28;margin-top:6px;">La estructura con la que se modela casi cualquier entidad del mundo real.</div>
# </div>

# %% [markdown]
# <div style="background:#FBE3E6;border:1px solid #A32C3A;border-left:6px solid #A32C3A;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#A32C3A;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 7.1</span>
#   <span style="border:1px solid #A32C3A;color:#711E28;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#711E28;margin:10px 0 6px 0;">Frecuencia de terminos</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# A partir del parrafo de la celda, construye un conteo de cuantas veces aparece cada palabra. Antes de contar, normaliza: sin diferencias por mayusculas, sin signos de puntuacion pegados a las palabras y sin contar las palabras vacias de la lista <code>irrelevantes</code>.<br><br>
# Reporta las cinco palabras mas frecuentes con su conteo, cuantas palabras aparecen una sola vez, y el porcentaje del texto que representan las cinco principales. Prohibido usar librerias de conteo.<br><br>
# <b>Cierre:</b> tu conteo trata "datos" y "dato" como palabras distintas. Argumenta en dos o tres lineas si eso es un defecto o una decision correcta, segun para que se vaya a usar el conteo.
# </div>
# </div>

# %%
# EJERCICIO 7.1
texto = """El analisis de datos no empieza con el modelo: empieza con los datos.
Un dato mal tipado se propaga por todo el proceso, y el modelo, por sofisticado
que sea, aprende del error. Por eso el trabajo de tipos y estructuras de datos
no es un tramite previo al analisis; es analisis."""

irrelevantes = {"el", "la", "los", "las", "de", "con", "y", "por", "un", "una", "que", "se", "no", "al", "es", "del", "a", "en"}

# Tu codigo:

# %% [markdown]
# <div style="background:#FBE3E6;border:1px solid #A32C3A;border-left:6px solid #A32C3A;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#A32C3A;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 7.2</span>
#   <span style="border:1px solid #A32C3A;color:#711E28;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#711E28;margin:10px 0 6px 0;">Catalogo anidado</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# El catalogo de la celda tiene productos con atributos y un sub-diccionario de existencias por bodega.<br><br>
# Implementa cuatro operaciones, cada una con su salida impresa: consultar las existencias de un producto en una bodega especifica <b>sin que el programa falle si el producto o la bodega no existen</b>; agregar una bodega nueva a un producto existente; aplicar un descuento del 15% solo a los productos cuyo total de existencias supere 100 unidades; y generar un listado de productos agotados (total en cero) que hoy no aparece en el catalogo pero podria aparecer manana.<br><br>
# <b>Cierre:</b> muestra dos formas distintas de leer una clave que puede no existir, con su comportamiento visible lado a lado, y argumenta en cual situacion de negocio preferirias cada una.
# </div>
# </div>

# %%
# EJERCICIO 7.2
catalogo = {
    "TEC-001": {"nombre": "Teclado mecanico", "precio": 289000, "existencias": {"BOG": 45, "MED": 30, "CAL": 12}},
    "MON-014": {"nombre": "Monitor 27 pulgadas", "precio": 1150000, "existencias": {"BOG": 8, "MED": 3}},
    "MOU-007": {"nombre": "Mouse inalambrico", "precio": 95000, "existencias": {"BOG": 120, "MED": 60, "CAL": 40}},
    "AUD-003": {"nombre": "Audifonos", "precio": 340000, "existencias": {"BOG": 0}},
}

# Tu codigo:

# %% [markdown]
# <div style="background:#FBE3E6;border:1px solid #A32C3A;border-left:6px solid #A32C3A;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#A32C3A;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 7.3</span>
#   <span style="border:1px solid #A32C3A;color:#711E28;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#711E28;margin:10px 0 6px 0;">Invertir la relacion</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# El diccionario de la celda asigna a cada estudiante su tutor. El area academica necesita la vista contraria: por cada tutor, el listado de sus estudiantes.<br><br>
# Construye esa vista invertida. Ten en cuenta que varios estudiantes comparten tutor, asi que una inversion directa perderia informacion: tu resultado debe conservar a todos. Reporta ademas el tutor con mas carga, los tutores con un solo estudiante y el promedio de estudiantes por tutor.<br><br>
# <b>Cierre:</b> ejecuta una inversion ingenua (una que simplemente intercambie clave por valor) e imprime cuantos registros sobreviven. Explica exactamente en que momento se pierde la informacion.
# </div>
# </div>

# %%
# EJERCICIO 7.3
tutorias = {
    "Acevedo": "Prof. Nieto", "Barrios": "Prof. Salas", "Caceres": "Prof. Nieto",
    "Delgado": "Prof. Ibarra", "Estrada": "Prof. Salas", "Fajardo": "Prof. Nieto",
    "Guzman": "Prof. Ibarra", "Herrera": "Prof. Vega", "Ibanez": "Prof. Salas",
    "Jimenez": "Prof. Nieto",
}

# Tu codigo:

# %% [markdown]
# <div style="background:#FBE3E6;border:1px solid #A32C3A;border-left:6px solid #A32C3A;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#A32C3A;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 7.4</span>
#   <span style="border:1px solid #A32C3A;color:#711E28;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">TRAMPA</span>
#   <div style="font-size:19px;font-weight:700;color:#711E28;margin:10px 0 6px 0;">Consolidacion de dos inventarios</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Dos bodegas envian su inventario. Debes consolidarlos en una sola estructura donde las referencias comunes sumen sus cantidades y las referencias exclusivas de cada bodega se conserven.<br><br>
# Ademas del consolidado, reporta: las referencias que existen en ambas bodegas, las que existen solo en la primera, las que existen solo en la segunda, y las referencias en las que la diferencia de cantidades entre bodegas supera las 50 unidades (posible desbalance de distribucion).<br><br>
# <b>Cierre:</b> prueba el atajo de fusionar los dos diccionarios directamente, sin sumar. Imprime el resultado para una referencia comun y explica que ocurrio con la cantidad de la otra bodega.
# </div>
# </div>

# %%
# EJERCICIO 7.4
bodega_norte = {"REF-01": 120, "REF-02": 45, "REF-03": 8, "REF-05": 200, "REF-07": 15}
bodega_sur   = {"REF-02": 30, "REF-03": 95, "REF-04": 60, "REF-05": 12, "REF-08": 70}

# Tu codigo:

# %% [markdown]
# <div style="background:#DEF5F8;border-left:10px solid #0B7285;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B7285;">BLOQUE 8</div>
#   <div style="font-size:26px;font-weight:800;color:#07505E;margin-top:2px;">Conjuntos: <code style='color:#07505E;'>set</code></div>
#   <div style="font-size:14px;color:#07505E;margin-top:6px;">Unicidad y pertenencia: dos preguntas que aparecen en todo proyecto de datos.</div>
# </div>

# %% [markdown]
# <div style="background:#DEF5F8;border:1px solid #0B7285;border-left:6px solid #0B7285;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B7285;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 8.1</span>
#   <span style="border:1px solid #0B7285;color:#07505E;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#07505E;margin:10px 0 6px 0;">Cruce de dos listas de asistencia</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Un evento academico registro la asistencia en dos sistemas distintos: el formulario de inscripcion previa y el registro en puerta. Ambas listas tienen duplicados por errores de digitacion del proceso.<br><br>
# Determina e imprime: cuantas personas distintas se inscribieron, cuantas distintas asistieron, quienes se inscribieron y efectivamente asistieron, quienes se inscribieron y no llegaron, quienes llegaron sin inscripcion previa, y quienes aparecen en un solo sistema (sin importar cual). Reporta ademas la tasa de conversion de inscritos a asistentes.<br><br>
# <b>Cierre:</b> la operacion que responde "quienes estan en uno solo de los dos sistemas" tiene un nombre propio en teoria de conjuntos. Identificala y explica como podrias obtener el mismo resultado combinando otras dos operaciones.
# </div>
# </div>

# %%
# EJERCICIO 8.1
inscritos = ["Ariza", "Bello", "Cortes", "Duran", "Bello", "Escalante",
             "Fonseca", "Ariza", "Gaviria", "Hoyos"]
asistentes = ["Bello", "Cortes", "Ibarra", "Duran", "Jaramillo", "Cortes",
              "Fonseca", "Klinger", "Bello", "Ariza"]

# Tu codigo:

# %% [markdown]
# <div style="background:#DEF5F8;border:1px solid #0B7285;border-left:6px solid #0B7285;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B7285;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 8.2</span>
#   <span style="border:1px solid #0B7285;color:#07505E;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#07505E;margin:10px 0 6px 0;">Control de permisos de un sistema</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Cada rol otorga un conjunto de permisos y cada usuario tiene uno o varios roles. La celda define ambos, mas los permisos exigidos por dos operaciones criticas.<br><br>
# Para cada usuario determina: sus permisos efectivos, si puede ejecutar cada operacion critica, y en caso negativo que permisos exactos le faltan. Reporta tambien que permisos tiene un usuario que <b>ningun</b> otro usuario tiene, y que permisos definidos en los roles no le sirven a nadie para las operaciones criticas.<br><br>
# Las verificaciones de "puede o no puede" deben resolverse con una <b>unica operacion entre conjuntos</b> que devuelva directamente un valor logico, no recorriendo permisos uno por uno.<br><br>
# <b>Cierre:</b> que ventaja tiene modelar los permisos como conjuntos frente a modelarlos como listas. Menciona al menos dos, una de correccion y una de rendimiento.
# </div>
# </div>

# %%
# EJERCICIO 8.2
roles = {
    "analista":  {"leer_datos", "exportar_csv", "ver_dashboard"},
    "editor":    {"leer_datos", "escribir_datos", "ver_dashboard"},
    "auditor":   {"leer_datos", "ver_logs", "exportar_csv", "ver_dashboard"},
    "admin":     {"leer_datos", "escribir_datos", "borrar_datos", "gestionar_usuarios", "ver_logs"},
}
usuarios = {
    "mrojas": ["analista"],
    "lgomez": ["editor", "analista"],
    "cperez": ["auditor"],
    "svargas": ["admin"],
    "tdiaz": ["editor"],
}
operacion_publicar = {"leer_datos", "escribir_datos", "ver_dashboard"}
operacion_depurar  = {"leer_datos", "borrar_datos", "ver_logs"}

# Tu codigo:

# %% [markdown]
# <div style="background:#DEF5F8;border:1px solid #0B7285;border-left:6px solid #0B7285;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B7285;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 8.3</span>
#   <span style="border:1px solid #0B7285;color:#07505E;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">TRAMPA</span>
#   <div style="font-size:19px;font-weight:700;color:#07505E;margin:10px 0 6px 0;">Los limites de un conjunto</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Cuatro experimentos, cada uno con su salida y su explicacion escrita:<br>
# <ol style="margin:6px 0 6px 18px;">
# <li>Intenta construir un conjunto que contenga una lista. Captura el error y reportalo.</li>
# <li>Construye un conjunto que contenga tuplas y verifica que si funciona.</li>
# <li>Crea un conjunto con los elementos <code>1</code>, <code>1.0</code>, <code>True</code> y <code>"1"</code>. Imprime su tamano y su contenido, y explica el resultado.</li>
# <li>Agrega diez elementos a un conjunto en un orden que tu elijas, imprimelo, y compara el orden de salida con el orden en que los agregaste.</li>
# </ol>
# <b>Cierre:</b> a partir de los cuatro experimentos, enuncia las tres condiciones que debe cumplir un valor para poder vivir dentro de un conjunto, y una consecuencia practica de que un conjunto no garantice orden.
# </div>
# </div>

# %%
# EJERCICIO 8.3
# Tu codigo:

# %% [markdown]
# <div style="background:#DEF5F8;border:1px solid #0B7285;border-left:6px solid #0B7285;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B7285;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 8.4</span>
#   <span style="border:1px solid #0B7285;color:#07505E;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#07505E;margin:10px 0 6px 0;">Deteccion de contenido duplicado</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# La celda contiene cinco titulos de articulos. Se considera que dos articulos son <b>sospechosamente similares</b> si comparten mas del 60% de sus palabras significativas (ignorando mayusculas, signos y palabras de menos de 4 letras).<br><br>
# Compara todos los pares posibles de titulos y reporta cuales pares superan el umbral, con su porcentaje de similitud. El porcentaje se define como la cantidad de palabras compartidas dividida entre la cantidad total de palabras distintas entre ambos titulos.<br><br>
# <b>Cierre:</b> la formula del porcentaje que acabas de implementar tiene nombre propio y se usa en motores de busqueda y sistemas antiplagio. Investiga como se llama y en dos lineas explica por que se divide entre el total de palabras distintas y no entre la longitud de uno de los titulos.
# </div>
# </div>

# %%
# EJERCICIO 8.4
titulos = [
    "Analisis predictivo de la desercion estudiantil universitaria",
    "Desercion estudiantil: un analisis predictivo en la universidad",
    "Modelos de series de tiempo para el consumo energetico",
    "Prediccion del consumo energetico con modelos de series de tiempo",
    "Analisis exploratorio de datos abiertos de movilidad urbana",
]

# Tu codigo:

# %% [markdown]
# <div style="background:#E7EAEE;border-left:10px solid #3D4852;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#3D4852;">BLOQUE 9</div>
#   <div style="font-size:26px;font-weight:800;color:#242B33;margin-top:2px;">Conversion de tipos: <code style='color:#242B33;'>casting</code></div>
#   <div style="font-size:14px;color:#242B33;margin-top:6px;">El punto exacto donde los datos del mundo real entran a tu programa.</div>
# </div>

# %% [markdown]
# <div style="background:#E7EAEE;border:1px solid #3D4852;border-left:6px solid #3D4852;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#3D4852;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 9.1</span>
#   <span style="border:1px solid #3D4852;color:#242B33;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#242B33;margin:10px 0 6px 0;">Ingesta de un archivo sucio</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# La celda simula las filas de un formulario web: todo llega como texto y algunos campos vienen mal. Los campos son documento, nombre, edad, promedio y activo.<br><br>
# Construye un proceso de ingesta que convierta cada fila a los tipos correctos (<code>str</code>, <code>str</code>, <code>int</code>, <code>float</code>, <code>bool</code>) y que <b>nunca se detenga</b> ante una fila defectuosa. Al final debes tener tres salidas: los registros validos ya tipados, un reporte de errores indicando fila, campo y motivo, y un resumen con el porcentaje de filas aprovechables.<br><br>
# Ojo con los campos <code>activo</code>: no todos usan la misma convencion.<br><br>
# <b>Cierre:</b> para las edades invalidas hay tres politicas posibles: descartar la fila, dejar el campo vacio o imputar un valor por defecto. Elige una, aplicala y justifica el impacto de tu eleccion sobre un analisis posterior de edad promedio.
# </div>
# </div>

# %%
# EJERCICIO 9.1
filas = [
    "1012456789,Valentina Ruiz,21,4.35,si",
    "79451236,Juan Gomez,treinta,3.80,1",
    "1128745,Laura Pena,19,4,0",
    "1098765432,Carlos Mora,23,3.9.1,SI",
    "1005544332,Diana Lopez,,4.50,no",
    "1077889900,Andres Nino,45,2.75,TRUE",
]

# Tu codigo:

# %% [markdown]
# <div style="background:#E7EAEE;border:1px solid #3D4852;border-left:6px solid #3D4852;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#3D4852;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 9.2</span>
#   <span style="border:1px solid #3D4852;color:#242B33;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#242B33;margin:10px 0 6px 0;">Cambio de estructura sin perder informacion</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Partiendo de las dos listas paralelas de la celda, produce en este orden y con la salida impresa de cada paso: una lista de pares, una estructura indexada por nombre, un conjunto de los valores unicos, una tupla del conjunto de nombres, y finalmente vuelve a reconstruir las dos listas originales por separado a partir de la estructura indexada.<br><br>
# Al terminar, compara la ultima reconstruccion contra las listas originales y determina si son identicas, incluyendo el orden.<br><br>
# <b>Cierre:</b> en alguno de los pasos se perdio informacion de forma irreversible. Identifica cual paso, que informacion se perdio, y por que la reconstruccion final aun asi pudo funcionar (o no).
# </div>
# </div>

# %%
# EJERCICIO 9.2
nombres = ["Alba", "Bravo", "Cano", "Bravo", "Duran", "Espinosa"]
puntajes = [88, 74, 92, 74, 61, 88]

# Tu codigo:

# %% [markdown]
# <div style="background:#E7EAEE;border:1px solid #3D4852;border-left:6px solid #3D4852;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#3D4852;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 9.3</span>
#   <span style="border:1px solid #3D4852;color:#242B33;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">TRAMPA</span>
#   <div style="font-size:19px;font-weight:700;color:#242B33;margin:10px 0 6px 0;">El museo de las conversiones inesperadas</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Evalua cada una de estas expresiones, imprimiendo resultado y tipo, o el error si falla. <b>Escribe tu prediccion antes de ejecutar cada una.</b><br>
# <ol style="margin:6px 0 6px 18px;">
# <li><code>int("3.9")</code> frente a <code>int(3.9)</code> frente a <code>int(-3.9)</code></li>
# <li><code>round(2.5)</code>, <code>round(3.5)</code>, <code>round(-2.5)</code>, <code>round(2.675, 2)</code></li>
# <li><code>bool("False")</code>, <code>bool("0")</code>, <code>bool(0.0)</code>, <code>bool([0])</code></li>
# <li><code>str(0.1 + 0.2)</code> frente a <code>format(0.1 + 0.2, ".20f")</code></li>
# <li><code>list("2026")</code> frente a <code>list([2026])</code> frente a <code>int("2 026")</code></li>
# <li><code>float("1e3")</code>, <code>int(True)</code>, <code>str(None)</code> y luego <code>int(str(None))</code></li>
# </ol>
# <b>Cierre:</b> elige las <b>dos</b> conversiones que consideres mas peligrosas en un proceso automatico de datos reales y describe un escenario concreto en el que cada una produciria un dato incorrecto sin generar ningun error visible.
# </div>
# </div>

# %%
# EJERCICIO 9.3
# Tu codigo:

# %% [markdown]
# <div style="background:#E7EAEE;border:1px solid #3D4852;border-left:6px solid #3D4852;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#3D4852;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 9.4</span>
#   <span style="border:1px solid #3D4852;color:#242B33;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#242B33;margin:10px 0 6px 0;">Presentacion y regreso</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">
# Los valores de la celda deben mostrarse en un reporte con esta presentacion: separador de miles con punto, separador decimal con coma, dos decimales, el simbolo de pesos al inicio y los negativos entre parentesis sin signo.<br><br>
# Escribe el proceso que convierte cada numero a ese texto. Luego escribe el proceso inverso: tomar esos textos ya formateados y recuperar el numero original. Compara el numero recuperado contra el original y reporta en cuales casos coinciden exactamente y en cuales no.<br><br>
# <b>Cierre:</b> este viaje de ida y vuelta no es reversible para todos los valores. Identifica cuales fallan, explica en que paso exacto se pierde la informacion, y propone que cambiarias en el formato de presentacion para que ningun valor se dane.
# </div>
# </div>

# %%
# EJERCICIO 9.4
valores = [1999990.5, -45300.756, 0.004, 12000000, -1234.5, 7.895]

# Tu codigo:

# %% [markdown]
# <div style="background:#0B4F6C;border-radius:12px;padding:26px 24px;margin:30px 0 10px 0;">
#   <div style="color:#8FD3E8;font-size:12px;letter-spacing:4px;font-weight:700;">RETO INTEGRADOR</div>
#   <div style="color:#FFFFFF;font-size:30px;font-weight:800;margin-top:6px;">Tablero de control de una cadena de tiendas</div>
#   <div style="color:#C9E7F2;font-size:15px;margin-top:10px;">Un solo problema. Los nueve tipos de datos. Cero librerias.</div>
# </div>

# %% [markdown]
# La celda contiene el volcado crudo de un sistema de punto de venta: cada linea es una transaccion en texto plano, con la calidad de datos que tiene un sistema real. Tu tarea es convertir ese texto en un tablero de control impreso.
#
# **Lo que debe producir tu programa:**
#
# 1. Un proceso de ingesta que lea el texto crudo, separe las transacciones, tipifique cada campo y aparte las lineas defectuosas en un registro de rechazos con el motivo de cada rechazo. Ninguna linea mala puede detener el proceso ni colarse al analisis.
# 2. Un catalogo consolidado, indexado por codigo de producto, donde cada producto acumule unidades vendidas, ingreso total y el conjunto de ciudades donde se vendio.
# 3. Un ranking de productos por ingreso y otro por unidades, senalando si algun producto ocupa posiciones muy distintas en los dos rankings y que significa eso comercialmente.
# 4. Un resumen por ciudad con ingreso total, ticket promedio y numero de transacciones, presentado como tabla alineada con formato de moneda.
# 5. La deteccion de estos casos, cada uno con su listado: productos vendidos en una sola ciudad; ciudades donde se vendio todo el catalogo; transacciones cuyo valor total no coincide con unidades por precio unitario (inconsistencia contable); y codigos de transaccion duplicados.
# 6. Un indicador logico final por ciudad que responda si la ciudad supero la meta de ingreso de $3.000.000 **y** vendio al menos cuatro productos distintos.
# 7. Un bloque de cierre en texto donde declares, para cada uno de los nueve tipos y estructuras del taller, **donde exactamente** lo usaste en tu solucion y por que ese y no otro. Si alguno no lo usaste, argumenta por que no era necesario.
#
# **Restricciones:**
#
# - Python puro. Sin `pandas`, `numpy`, `collections`, `re`, `csv` ni `datetime`.
# - Ningun valor "magico" escrito a mano que debiera calcularse a partir de los datos.
# - El programa debe seguir funcionando si se agregan lineas nuevas al volcado. Compruebalo agregando tu mismo dos transacciones, una valida y una defectuosa.
#
# **Criterio de cierre:** al final, en una celda de texto, responde en maximo 10 lineas: cual fue la decision de diseno mas dificil del reto y que alternativa descartaste.

# %%
# RETO INTEGRADOR
volcado = """TRX-1001|BOG|TEC-001|2|289000|578000
TRX-1002|MED|MON-014|1|1150000|1150000
TRX-1003|BOG|MOU-007|5|95000|475000
TRX-1004|CAL|TEC-001|3|289000|867000
TRX-1005|BOG|MON-014|2|1150000|2300000
TRX-1006|MED|MOU-007|4|95000|380000
TRX-1007|BOG|AUD-003|1|340000|340000
TRX-1008|CAL|MOU-007|10|95000|950000
TRX-1009|MED|TEC-001|abc|289000|289000
TRX-1010|BOG|TEC-001|1|289000|300000
TRX-1011|CAL|MON-014|1|1150000|1150000
TRX-1003|BOG|AUD-003|2|340000|680000
TRX-1012|MED||3|95000|285000
TRX-1013|CAL|AUD-003|2|340000|680000
TRX-1014|BOG|MOU-007|7|95000|665000
TRX-1015|MED|MON-014|1|1150000
TRX-1016|CAL|TEC-001|4|289000|1156000"""

# Tu codigo:

# %% [markdown]
# ---
#
# ## Autoevaluacion antes de entregar
#
# <div style="background:#E7EAEE;border-radius:8px;padding:4px 18px 14px 18px;margin:14px 0;">
# <table style="width:100%;border-collapse:collapse;font-size:14px;color:#242B33;">
#   <tr style="border-bottom:2px solid #3D4852;">
#     <th style="padding:10px 8px;text-align:left;">Verifica que...</th>
#     <th style="padding:10px 8px;text-align:center;width:90px;">Listo</th>
#   </tr>
#   <tr><td style="padding:8px;">Cada celda de codigo se ejecuta de arriba a abajo sin errores no controlados.</td><td style="padding:8px;text-align:center;">[ ]</td></tr>
#   <tr><td style="padding:8px;">Respondiste por escrito la pregunta de cierre de los 36 ejercicios.</td><td style="padding:8px;text-align:center;">[ ]</td></tr>
#   <tr><td style="padding:8px;">No usaste librerias externas donde el enunciado lo prohibia.</td><td style="padding:8px;text-align:center;">[ ]</td></tr>
#   <tr><td style="padding:8px;">Los nombres de tus variables describen el dato, no la letra del alfabeto.</td><td style="padding:8px;text-align:center;">[ ]</td></tr>
#   <tr><td style="padding:8px;">En los ejercicios marcados TRAMPA, dejaste registrada tu prediccion inicial.</td><td style="padding:8px;text-align:center;">[ ]</td></tr>
#   <tr><td style="padding:8px;">El reto integrador sigue funcionando con las dos transacciones que agregaste.</td><td style="padding:8px;text-align:center;">[ ]</td></tr>
#   <tr><td style="padding:8px;">Guardaste una copia en tu Drive: <i>Archivo &gt; Guardar una copia en Drive</i>.</td><td style="padding:8px;text-align:center;">[ ]</td></tr>
# </table>
# </div>
#
# ## Como se califica
#
# <div style="display:block;">
# <table style="width:100%;border-collapse:collapse;font-size:14px;">
#   <tr style="background:#0B4F6C;color:#FFFFFF;">
#     <th style="padding:10px;text-align:left;">Criterio</th>
#     <th style="padding:10px;text-align:left;">Que se observa</th>
#     <th style="padding:10px;text-align:center;">Peso</th>
#   </tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;font-weight:700;">Correccion</td><td style="padding:9px;">El programa produce el resultado que pide el enunciado, incluidos los casos limite.</td><td style="padding:9px;text-align:center;">35%</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;font-weight:700;">Eleccion del tipo</td><td style="padding:9px;">La estructura usada es la adecuada al problema y esta justificada.</td><td style="padding:9px;text-align:center;">25%</td></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;font-weight:700;">Razonamiento escrito</td><td style="padding:9px;">Las preguntas de cierre estan respondidas con argumento y con evidencia del propio codigo.</td><td style="padding:9px;text-align:center;">25%</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;font-weight:700;">Robustez y claridad</td><td style="padding:9px;">Manejo de datos defectuosos, nombres significativos, salidas legibles.</td><td style="padding:9px;text-align:center;">15%</td></tr>
# </table>
# </div>
#
# <div style="background:#FDEBD8;border-left:6px solid #B35309;border-radius:6px;padding:14px 18px;margin:18px 0;color:#1A1A1A;">
# <b>Nota sobre el uso de asistentes de IA:</b> puedes consultarlos, pero la entrega debe incluir tus propias respuestas a las preguntas de cierre y debes poder explicar cualquier linea de tu codigo si se te pregunta en clase. Un codigo perfecto que no puedes explicar vale menos que uno imperfecto que si.
# </div>
#
# <div style="text-align:center;color:#3D4852;font-size:13px;margin-top:26px;">
# DataXperience &middot; Taller 02 &middot; Tipos de datos en Python
# </div>
