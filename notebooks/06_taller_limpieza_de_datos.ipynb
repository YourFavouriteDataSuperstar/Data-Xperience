# %% [markdown]
# <a href="https://colab.research.google.com/github/YourFavouriteDataSuperstar/Data-Xperience/blob/main/notebooks/06_taller_limpieza_de_datos.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# <div style="background:#0B4F6C;border-radius:12px;padding:32px 28px;margin:14px 0;">
#   <div style="color:#8FD3E8;font-size:13px;letter-spacing:5px;font-weight:700;">DATAXPERIENCE</div>
#   <div style="color:#FFFFFF;font-size:38px;font-weight:800;line-height:1.15;margin-top:8px;">Taller de limpieza de datos</div>
#   <div style="color:#C9E7F2;font-size:16px;margin-top:12px;">30 ejercicios + 1 reto integrador sobre la GEIH del DANE (modulo de Personas, junio 2025). Nulos, duplicados, atipicos, imputacion, agregacion, escalas y pipeline.</div>
#   <div style="margin-top:18px;">
#     <span style="background:#FFFFFF;color:#0B4F6C;padding:5px 14px;border-radius:14px;font-size:12px;font-weight:700;">NIVEL: INTERMEDIO</span>
#     <span style="background:#8FD3E8;color:#0B4F6C;padding:5px 14px;border-radius:14px;font-size:12px;font-weight:700;margin-left:6px;">DURACION: 4-5 HORAS</span>
#     <span style="background:#8FD3E8;color:#0B4F6C;padding:5px 14px;border-radius:14px;font-size:12px;font-weight:700;margin-left:6px;">DATOS REALES</span>
#   </div>
# </div>

# %% [markdown]
# ## Como funciona este taller
#
# Este taller **no es un tutorial**. No encontraras explicaciones nuevas ni el nombre del metodo que debes usar: cada ejercicio plantea una situacion y el resultado esperado, y elegir la herramienta es tu trabajo. Todo lo necesario esta en el notebook **05 - Limpieza de datos en profundidad**.
#
# Todos los ejercicios trabajan sobre **el mismo archivo real**: la GEIH de junio de 2025. Y como en un proyecto de verdad, **el orden importa**: la tabla que dejas limpia en un bloque es el insumo del siguiente. Si te saltas un bloque, el siguiente no va a cuadrar.
#
# Para cada ejercicio entrega **codigo + una frase de conclusion** en una celda de texto debajo. Un numero sin interpretacion no es una respuesta.
#
# <div style="background:#E7EAEE;border-radius:8px;padding:14px 18px;margin:16px 0;font-size:14px;color:#1A1A1A;">
# <b>Convenciones.</b> <code>crudo</code> es el archivo tal como llega. <code>df</code> es tu tabla de trabajo. Cuando un ejercicio diga <b>"consolida"</b>, guarda el resultado en <code>df</code>; en los demas, trabaja sobre copias. Los ejercicios marcados <b>ANALISIS</b> piden una interpretacion mas larga; los marcados <b>DISENO</b> piden que tomes una decision y la justifiques.
# </div>

# %% [markdown]
# ## Mapa del taller
#
# <div style="overflow-x:auto;">
# <table style="width:100%;border-collapse:collapse;font-size:14px;">
#   <tr style="background:#0B4F6C;color:#FFFFFF;"><th style="padding:10px;text-align:left;">Bloque</th><th style="padding:10px;text-align:left;">Tema</th><th style="padding:10px;text-align:left;">Eje de trabajo</th><th style="padding:10px;text-align:center;">Ejercicios</th></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">1</td><td style="padding:9px;">Diccionario, tipos y centinelas</td><td style="padding:9px;">Hacer legible el archivo</td><td style="padding:9px;text-align:center;">5</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;">2</td><td style="padding:9px;">Nulos estructurales y reales</td><td style="padding:9px;">Decidir que falta de verdad</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">3</td><td style="padding:9px;">Duplicados y reglas de validacion</td><td style="padding:9px;">Encontrar lo imposible</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;">4</td><td style="padding:9px;">Datos atipicos</td><td style="padding:9px;">Detectar, contextualizar, tratar</td><td style="padding:9px;text-align:center;">5</td></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">5</td><td style="padding:9px;">Imputacion</td><td style="padding:9px;">Experimentar y medir</td><td style="padding:9px;text-align:center;">5</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;">6</td><td style="padding:9px;">Agregacion con factor de expansion</td><td style="padding:9px;">Cifras que representan al pais</td><td style="padding:9px;text-align:center;">4</td></tr>
#   <tr style="background:#F4F6F8;color:#242B33;"><td style="padding:9px;">7</td><td style="padding:9px;">Escalas, logaritmos y codificacion</td><td style="padding:9px;">Preparar para modelar</td><td style="padding:9px;text-align:center;">3</td></tr>
#   <tr style="color:#242B33;"><td style="padding:9px;">R</td><td style="padding:9px;">Reto integrador</td><td style="padding:9px;">Pipeline + informe</td><td style="padding:9px;text-align:center;">1</td></tr>
# </table>
# </div>

# %%
# ============================================================
#  DATOS DEL TALLER - EJECUTA ESTA CELDA PRIMERO
#  GEIH junio 2025 - modulo de Personas + 6 variables de Ocupados
#  No modifiques esta celda.
# ============================================================
import os, warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 60)
pd.set_option("display.float_format", lambda v: f"{v:,.2f}")
sns.set_theme(style="whitegrid")

URL   = "https://raw.githubusercontent.com/YourFavouriteDataSuperstar/Data-Xperience/main/notebooks/data/geih_2025_06_personas.csv"
LOCAL = "data/geih_2025_06_personas.csv"
crudo = pd.read_csv(LOCAL if os.path.exists(LOCAL) else URL, low_memory=False)

# Diccionario oficial resumido (GEIH 2025). Usalo: es parte del enunciado.
DICCIONARIO = {
    "DIRECTORIO": "directorio", "SECUENCIA_P": "secuencia_p", "ORDEN": "orden",
    "CLASE": "clase", "DPTO": "dpto", "FEX_C18": "fex",
    "P3271": "sexo", "P6040": "edad", "P6030S1": "mes_nac", "P6030S3": "anio_nac",
    "P6050": "parentesco", "P6070": "estado_civil", "P6080": "etnia", "P2057": "campesino",
    "P6081": "padre_en_hogar", "P6083": "madre_en_hogar",
    "P6090": "afiliado_salud", "P6100": "regimen_salud",
    "P6160": "sabe_leer", "P6170": "estudia", "P3042": "nivel_educativo",
    "INGLABO": "ingreso_laboral", "P6800": "horas_semana", "P6430": "posicion_ocupacional",
    "P6426": "meses_trabajo", "RAMA2D_R4": "rama_actividad", "P6920": "cotiza_pension",
}
CODIGOS = {
    "sexo": {1: "Hombre", 2: "Mujer"},
    "clase": {1: "Cabecera", 2: "Rural"},
    "afiliado_salud": {1: "Si", 2: "No", 9: "No sabe"},
    "regimen_salud": {1: "Contributivo", 2: "Especial", 3: "Subsidiado", 9: "No sabe"},
    "sabe_leer": {1: "Si", 2: "No"}, "estudia": {1: "Si", 2: "No"},
    "campesino": {1: "Si", 2: "No", 9: "No sabe"},
    "etnia": {1: "Indigena", 2: "Gitano", 3: "Raizal", 4: "Palenquero", 5: "Negro/afro", 6: "Ninguno"},
    "estado_civil": {1: "Union libre <2a", 2: "Union libre >=2a", 3: "Casado(a)", 4: "Separado(a)", 5: "Viudo(a)", 6: "Soltero(a)"},
    "nivel_educativo": {1: "Ninguno", 2: "Preescolar", 3: "Primaria", 4: "Secundaria", 5: "Media academica", 6: "Media tecnica",
                        7: "Normalista", 8: "Tecnica", 9: "Tecnologica", 10: "Universitaria", 11: "Especializacion",
                        12: "Maestria", 13: "Doctorado", 99: "No sabe"},
    "posicion_ocupacional": {1: "Empleado particular", 2: "Empleado del gobierno", 3: "Empleado domestico", 4: "Cuenta propia",
                             5: "Patron/empleador", 6: "Familiar sin remuneracion", 7: "Sin remuneracion otras empresas",
                             8: "Jornalero/peon", 9: "Otro"},
    "cotiza_pension": {1: "Si", 2: "No", 3: "Pensionado"},
    "padre_en_hogar": {1: "Vive en el hogar", 2: "Vive en otro hogar", 3: "Fallecido"},
    "madre_en_hogar": {1: "Vive en el hogar", 2: "Vive en otro hogar", 3: "Fallecida"},
}
DEPARTAMENTOS = {5: "Antioquia", 8: "Atlantico", 11: "Bogota D.C.", 13: "Bolivar", 15: "Boyaca", 17: "Caldas", 18: "Caqueta",
    19: "Cauca", 20: "Cesar", 23: "Cordoba", 25: "Cundinamarca", 27: "Choco", 41: "Huila", 44: "La Guajira", 47: "Magdalena",
    50: "Meta", 52: "Narino", 54: "Norte de Santander", 63: "Quindio", 66: "Risaralda", 68: "Santander", 70: "Sucre",
    73: "Tolima", 76: "Valle del Cauca", 81: "Arauca", 85: "Casanare", 86: "Putumayo", 88: "San Andres", 91: "Amazonas",
    94: "Guainia", 95: "Guaviare", 97: "Vaupes", 99: "Vichada"}

print("Archivo cargado:", crudo.shape)

# %% [markdown]
# <div style="background:#E1E8F8;border-left:6px solid #2B4C9B;border-radius:8px;padding:14px 18px;margin:16px 0;">
#   <b style="color:#1B3268;">Regla de trabajo con el original</b><br>
#   <span style="color:#1A1A1A;font-size:14px;"><code>crudo</code> es tu unica copia del archivo del DANE. Nunca lo sobrescribas: empieza con <code>df = crudo.copy()</code> y consolida en <code>df</code> solo cuando un ejercicio lo pida. Si lo danas, vuelve a ejecutar la celda de datos.</span>
# </div>
#
# ---

# %% [markdown]
# <div style="background:#D6EEF6;border-left:10px solid #0B4F6C;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B4F6C;">BLOQUE 1</div>
#   <div style="font-size:26px;font-weight:800;color:#083A50;margin-top:2px;">Diccionario, tipos y centinelas</div>
#   <div style="font-size:14px;color:#083A50;margin-top:6px;">El archivo llega en codigos. Hazlo legible sin perder informacion.</div>
# </div>

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.1</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Renombrar y tipar</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Crea <code>df</code> a partir de <code>crudo</code> con los nombres legibles de <code>DICCIONARIO</code>. Luego muestra, en una sola tabla, el tipo de dato de cada columna, su numero de valores unicos y su porcentaje de nulos. <b>Consolida.</b></div>
# </div>

# %%
# EJERCICIO 1.1
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.2</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Que columnas NO son cantidades</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">A partir de la tabla anterior, lista las columnas que pandas cargo como numericas pero que en realidad son <b>categoricas</b> (codigos). Justifica con una frase por que <code>dpto.mean()</code> no tiene sentido aunque se pueda calcular.</div>
# </div>

# %%
# EJERCICIO 1.2
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.3</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Cazar centinelas</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Sin usar el notebook 05 como guia, recorre <code>CODIGOS</code> y encuentra que columnas tienen codigos de <i>"No sabe"</i>. Para cada una cuenta cuantos registros los usan. Luego verifica si el codigo <code>99</code> de <code>nivel_educativo</code> aparece en este mes.</div>
# </div>

# %%
# EJERCICIO 1.3
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.4</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Etiquetar con seguridad</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Convierte todas las columnas de <code>CODIGOS</code> a etiquetas de texto tipo <code>category</code>, <b>dejando los "No sabe" como <code>NaN</code></b>. Demuestra que no se creo ningun nulo nuevo por codigos fuera del diccionario (compara nulos antes y despues). Mapea tambien <code>dpto</code> a <code>departamento</code>. <b>Consolida.</b></div>
# </div>

# %%
# EJERCICIO 1.4
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 1.5</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Orden que importa</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Declara <code>nivel_educativo</code> como categoria <b>ordenada</b> y demuestra que el orden funciona: filtra a las personas con nivel educativo <i>mayor o igual</i> a <code>Universitaria</code> usando una comparacion, no una lista. Cuantas son? <b>Consolida.</b></div>
# </div>

# %%
# EJERCICIO 1.5
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border-left:10px solid #0B4F6C;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B4F6C;">BLOQUE 2</div>
#   <div style="font-size:26px;font-weight:800;color:#083A50;margin-top:2px;">Nulos estructurales y reales</div>
#   <div style="font-size:14px;color:#083A50;margin-top:6px;">No todo NaN es un hueco. Demuestra cual es cual.</div>
# </div>

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 2.1</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Mapa de faltantes</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Grafica el porcentaje de nulos por columna (solo las que tienen alguno), ordenado de mayor a menor. Agrupa visualmente (por color o por etiqueta) las columnas del modulo Ocupados frente a las del modulo Personas.</div>
# </div>

# %%
# EJERCICIO 2.1
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 2.2</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Probar que un nulo es estructural</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Para <code>sabe_leer</code>, <code>estudia</code>, <code>estado_civil</code> y <code>regimen_salud</code>, demuestra con codigo cual es la variable que gobierna el flujo (edad minima o afiliacion) y confirma que <b>el 100% de los nulos</b> cumple esa condicion. Presenta el resultado como una tabla: columna, condicion de flujo, % de nulos explicados.</div>
# </div>

# %%
# EJERCICIO 2.2
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 2.3</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Faltantes reales de ingreso</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Entre los ocupados, separa los nulos de <code>ingreso_laboral</code> en <b>estructurales</b> (trabajadores sin remuneracion) y <b>reales</b>. Cuantos hay de cada tipo? Que posicion ocupacional domina entre los reales?</div>
# </div>

# %%
# EJERCICIO 2.3
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 2.4</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">DISENO</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Hacer explicito lo estructural</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Para <code>regimen_salud</code>, reemplaza los nulos estructurales (no afiliados) por una categoria explicita <code>"No afiliado"</code> y deja los reales como <code>NaN</code>. Muestra el <code>value_counts(dropna=False)</code> final. <b>Consolida.</b></div>
# </div>

# %%
# EJERCICIO 2.4
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border-left:10px solid #0B4F6C;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B4F6C;">BLOQUE 3</div>
#   <div style="font-size:26px;font-weight:800;color:#083A50;margin-top:2px;">Duplicados y reglas de validacion</div>
#   <div style="font-size:14px;color:#083A50;margin-top:6px;">Lo que no deberia existir y lo que se contradice.</div>
# </div>

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 3.1</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Una llave que lo es</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Demuestra que <code>(directorio, secuencia_p, orden)</code> identifica de forma unica a cada persona y que <code>directorio</code> solo <b>no</b> lo hace. Cuantas personas tiene la vivienda mas grande de la muestra?</div>
# </div>

# %%
# EJERCICIO 3.1
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 3.2</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Simular y resolver duplicados</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Construye una version <code>sucia</code> de <code>df</code> anadiendo 200 filas duplicadas exactas y 100 duplicados de llave donde <code>horas_semana</code> se incremento en 5. Elimina primero los exactos y luego los de llave conservando <b>la fila con menos horas</b> (asume que la mayor es el error). Verifica que vuelves exactamente al tamano de <code>df</code>.</div>
# </div>

# %%
# EJERCICIO 3.2
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 3.3</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Reglas de dominio</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Escribe una funcion <code>validar(d)</code> con al menos <b>ocho reglas</b> de dominio, de las cuales al menos tres no esten en el notebook 05 (piensa en <code>estudia</code>, <code>cotiza_pension</code>, <code>parentesco</code>, <code>mes_nac</code>, <code>fex</code>). Devuelve un reporte con violaciones y porcentaje. Comenta cada regla en el codigo.</div>
# </div>

# %%
# EJERCICIO 3.3
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 3.4</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">DISENO</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Inspeccionar antes de actuar</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Para cada regla violada, muestra hasta 5 registros y decide: corregir, anular, marcar o eliminar. Aplica la decision y registra en una columna <code>flags</code> (texto) que reglas viola cada fila. <b>Consolida.</b></div>
# </div>

# %%
# EJERCICIO 3.4
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border-left:10px solid #0B4F6C;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B4F6C;">BLOQUE 4</div>
#   <div style="font-size:26px;font-weight:800;color:#083A50;margin-top:2px;">Datos atipicos</div>
#   <div style="font-size:14px;color:#083A50;margin-top:6px;">Detectar es facil. Contextualizar y decidir es el trabajo.</div>
# </div>

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.1</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Tres metodos sobre las horas</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Aplica IQR (k = 1.5), z-score (|z| > 3) y z robusto con MAD (> 3.5) a <code>horas_semana</code> entre los ocupados. Construye una tabla comparativa con el numero de atipicos de cada metodo y el valor minimo que marca cada uno. Compara con la regla fisica de 84 horas: cual metodo se acerca mas?</div>
# </div>

# %%
# EJERCICIO 4.1
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.2</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Atipicos por grupo</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Detecta atipicos de <code>ingreso_laboral</code> con MAD <b>dentro de cada posicion ocupacional</b> (usa <code>groupby().transform</code>). Compara el conjunto de personas marcadas con la deteccion global: cuantas se marcan solo en una de las dos? Explica con un ejemplo concreto por que un ingreso puede ser atipico entre empleados domesticos y normal entre patrones.</div>
# </div>

# %%
# EJERCICIO 4.2
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.3</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">DISENO</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">El contexto decide</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Toma los 20 ingresos mas altos. Para cada uno muestra posicion ocupacional, nivel educativo, edad, horas y departamento. Clasificalos a mano en <i>plausible</i> / <i>dudoso</i> con un criterio explicito que escribas en una celda de texto. Cuantos quedan en cada grupo?</div>
# </div>

# %%
# EJERCICIO 4.3
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.4</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Efecto de cada tratamiento</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Para <code>ingreso_laboral</code> calcula media, mediana, desviacion y asimetria bajo cuatro escenarios: original, eliminando atipicos MAD, winsorizando en p1-p99 y winsorizando en p5-p95. Presenta una tabla. Que tratamiento cambia mas la media y cual la asimetria?</div>
# </div>

# %%
# EJERCICIO 4.4
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 4.5</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Marcar sin destruir</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Anade a <code>df</code> las columnas <code>flag_ingreso_atipico</code> (MAD global), <code>flag_horas_atipicas</code> (regla de 84 h) e <code>ingreso_wins</code> (winsorizado p1-p99). Demuestra con una comparacion que <code>ingreso_laboral</code> no cambio. <b>Consolida.</b></div>
# </div>

# %%
# EJERCICIO 4.5
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border-left:10px solid #0B4F6C;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B4F6C;">BLOQUE 5</div>
#   <div style="font-size:26px;font-weight:800;color:#083A50;margin-top:2px;">Imputacion</div>
#   <div style="font-size:14px;color:#083A50;margin-top:6px;">Borra a proposito, imputa, mide. Solo asi sabes que metodo sirve.</div>
# </div>

# %%
# Funciones de apoyo para el bloque 5 (puedes usarlas o escribir las tuyas)
def borrar_mcar(d, col, frac, rng):
    idx = rng.choice(d.index, size=int(len(d) * frac), replace=False)
    mask = pd.Series(False, index=d.index); mask.loc[idx] = True
    d.loc[mask, col] = np.nan
    return mask

def evaluar(imputado, original, col, mask):
    real, est = original.loc[mask, col], imputado.loc[mask, col]
    return {"MAE": (est - real).abs().mean(),
            "RMSE": np.sqrt(((est - real) ** 2).mean()),
            "sesgo_media": imputado[col].mean() - original[col].mean(),
            "razon_desv": imputado[col].std() / original[col].std()}

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.1</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Montar el experimento</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Construye <code>base</code> con los ocupados que tienen ingreso positivo y las columnas <code>ingreso_wins</code>, <code>horas_semana</code>, <code>edad</code>, <code>sexo</code>, <code>nivel_educativo</code>, <code>posicion_ocupacional</code>, <code>clase</code>, sin nulos. Guarda <code>original = base.copy()</code>. Borra (MCAR, semilla 7) el <b>20%</b> de <code>horas_semana</code> y el 20% de <code>ingreso_wins</code>, guardando las mascaras.</div>
# </div>

# %%
# EJERCICIO 5.1
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.2</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Cinco metodos sobre las horas</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Imputa <code>horas_semana</code> con media, mediana, mediana por grupo (<code>posicion_ocupacional x sexo</code>), KNN (k = 15, con escalado previo) e <code>IterativeImputer</code>. Evalua con <code>evaluar()</code> y presenta una tabla ordenada por MAE. Que metodo gana y por que crees que gana en <i>esta</i> variable?</div>
# </div>

# %%
# EJERCICIO 5.2
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.3</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Que variables ve KNN</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Repite KNN para <code>ingreso_wins</code> dos veces: una usando solo <code>horas_semana</code> y <code>edad</code> como vecindad, y otra anadiendo <code>nivel_educativo</code> codificado ordinalmente y <code>posicion_ocupacional</code> en one-hot (todo escalado). Compara el MAE. Que aprendes sobre KNN?</div>
# </div>

# %%
# EJERCICIO 5.3
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.4</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Borrado MAR y sesgo</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Escribe <code>borrar_mar</code> para que la probabilidad de borrar <code>ingreso_wins</code> crezca con <code>horas_semana</code> (quienes mas trabajan responden menos). Borra el 20%, imputa con mediana global y con mediana por grupo (<code>posicion_ocupacional x rango de horas</code>), y compara el <code>sesgo_media</code>. Cual corrige el sesgo y por que?</div>
# </div>

# %%
# EJERCICIO 5.4
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 5.5</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">DISENO</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Aplicar con bandera</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Imputa en <code>df</code> los faltantes <b>reales</b> de <code>ingreso_laboral</code> (no los estructurales) con el metodo que mejor resulto en 5.2-5.4, crea la columna <code>ingreso_imputado</code> (booleana) y reporta cuantas celdas cambiaste. <b>Consolida.</b></div>
# </div>

# %%
# EJERCICIO 5.5
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border-left:10px solid #0B4F6C;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B4F6C;">BLOQUE 6</div>
#   <div style="font-size:26px;font-weight:800;color:#083A50;margin-top:2px;">Agregacion con factor de expansion</div>
#   <div style="font-size:14px;color:#083A50;margin-top:6px;">Cifras que hablan del pais, no de la muestra.</div>
# </div>

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 6.1</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Muestra vs. poblacion</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Construye una tabla por <code>rango_edad</code> (crea los rangos 0-14, 15-28, 29-40, 41-59, 60+) con: encuestados, poblacion representada (suma de <code>fex</code>), % de la muestra y % de la poblacion. Que grupo esta mas sobre-representado en la muestra?</div>
# </div>

# %%
# EJERCICIO 6.1
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 6.2</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Mediana ponderada</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Implementa una funcion <code>mediana_pond(d, col, peso)</code> (ordena por <code>col</code>, acumula <code>peso</code>, toma el valor donde el acumulado cruza el 50%). Aplicala para obtener el ingreso laboral mediano ponderado por departamento. Muestra los 5 mas altos y los 5 mas bajos e indica cuantos encuestados hay detras de cada uno.</div>
# </div>

# %%
# EJERCICIO 6.2
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 6.3</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Tasas con denominador correcto</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Calcula la <b>tasa de cotizacion a pension</b> (ponderada) por <code>posicion_ocupacional x sexo</code> con <code>pivot_table</code>. Marca (por ejemplo con un asterisco o con color) las celdas con menos de 50 encuestados. Que celdas no deberias publicar?</div>
# </div>

# %%
# EJERCICIO 6.3
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 6.4</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">La misma cifra, cuatro formas</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Calcula el ingreso laboral promedio de las mujeres ocupadas de cuatro maneras: media muestral, media ponderada, mediana muestral, mediana ponderada. Presentalas juntas y explica en tres frases por que difieren y cual reportarias en un informe.</div>
# </div>

# %%
# EJERCICIO 6.4
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border-left:10px solid #0B4F6C;border-radius:8px;padding:18px 22px;margin:26px 0 8px 0;">
#   <div style="font-size:12px;letter-spacing:3px;font-weight:700;color:#0B4F6C;">BLOQUE 7</div>
#   <div style="font-size:26px;font-weight:800;color:#083A50;margin-top:2px;">Escalas, logaritmos y codificacion</div>
#   <div style="font-size:14px;color:#083A50;margin-top:6px;">Preparar las variables para que un modelo las entienda.</div>
# </div>

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 7.1</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Tres escalas, una tabla</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Escala <code>ingreso_wins</code>, <code>horas_semana</code> y <code>edad</code> con Min-Max, estandarizacion y escala robusta (a mano, sin scikit-learn). Presenta media, desviacion, minimo, mediana y maximo de cada version. Para cada escala escribe una frase sobre que le pasa al ingreso.</div>
# </div>

# %%
# EJERCICIO 7.1
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 7.2</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">ANALISIS</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Brecha en log</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Calcula la brecha de ingreso <code>Cabecera</code> vs <code>Rural</code> como diferencia de medias de <code>log1p(ingreso)</code>, e interpretala en porcentaje. Repite la brecha <b>dentro de cada nivel educativo</b> (solo niveles con 100 o mas ocupados). Se mantiene al controlar por educacion? Grafica.</div>
# </div>

# %%
# EJERCICIO 7.2
# Tu codigo:

# %% [markdown]
# <div style="background:#D6EEF6;border:1px solid #0B4F6C;border-left:6px solid #0B4F6C;border-radius:8px;padding:14px 18px;margin:18px 0 6px 0;">
#   <span style="background:#0B4F6C;color:#FFFFFF;padding:3px 12px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:2px;">EJERCICIO 7.3</span>
#   <span style="border:1px solid #0B4F6C;color:#083A50;padding:3px 10px;border-radius:14px;font-size:11px;font-weight:700;letter-spacing:1px;margin-left:8px;">APLICACION</span>
#   <div style="font-size:19px;font-weight:700;color:#083A50;margin:10px 0 6px 0;">Codificar sin inventar orden</div>
#   <div style="font-size:14px;color:#1A1A1A;line-height:1.55;">Construye una matriz <code>X</code> lista para un modelo con: <code>log_ingreso</code>, <code>horas_semana</code> y <code>edad</code> estandarizadas; <code>nivel_educativo</code> como codigo ordinal; <code>sexo</code>, <code>clase</code> y <code>posicion_ocupacional</code> en one-hot con <code>drop_first=True</code>. Reporta la forma de <code>X</code> y justifica en una frase por que <code>departamento</code> no va como entero.</div>
# </div>

# %%
# EJERCICIO 7.3
# Tu codigo:

# %% [markdown]
# <div style="background:#0B4F6C;border-radius:12px;padding:24px 26px;margin:30px 0 10px 0;">
#   <div style="color:#8FD3E8;font-size:12px;letter-spacing:4px;font-weight:700;">RETO INTEGRADOR</div>
#   <div style="color:#FFFFFF;font-size:28px;font-weight:800;margin-top:4px;">Pipeline reproducible + informe de calidad</div>
#   <div style="color:#C9E7F2;font-size:15px;margin-top:10px;line-height:1.6;">
#   Empaqueta <b>todo</b> lo que hiciste en los bloques 1 a 5 en una funcion <code>limpiar_geih(crudo, ...)</code> que reciba el archivo original y devuelva <code>(tabla_limpia, reporte)</code>, donde <code>reporte</code> es una lista de frases con el efecto de cada paso (filas, nulos, reemplazos, imputaciones, banderas). Requisitos:
#   <ol style="margin-top:8px;">
#     <li>No modifica la entrada.</li>
#     <li>Los parametros (diccionario, centinelas, umbrales, metodo de imputacion) entran como argumentos, no estan quemados en el cuerpo.</li>
#     <li>Al correrla sobre <code>crudo</code> devuelve exactamente la misma tabla que <code>df</code> consolidado (demuestralo con <code>equals</code> o comparando resumenes).</li>
#     <li>Exporta la tabla limpia a Parquet y a CSV y compara tamanos.</li>
#     <li>Escribe un <b>informe de calidad</b> en una celda de texto (maximo 300 palabras) dirigido a alguien que no programa: que encontraste, que decidiste, que no tocaste y por que.</li>
#   </ol>
#   <b>Bonus:</b> descarga otro mes de la GEIH 2025 del portal de microdatos del DANE, construye el mismo archivo y pasa tu funcion sin cambiar una linea. Compara los dos reportes.
#   </div>
# </div>

# %%
# RETO INTEGRADOR
def limpiar_geih(crudo, diccionario=DICCIONARIO, codigos=CODIGOS, departamentos=DEPARTAMENTOS, max_horas=84, p_wins=(0.01, 0.99), metodo_imputacion="grupo"):
    reporte = []
    # Tu codigo:

    return None, reporte

# %% [markdown]
# ---
# <div style="background:#0B4F6C;border-radius:12px;padding:20px 24px;margin-top:24px;">
#   <div style="color:#8FD3E8;font-size:12px;letter-spacing:4px;font-weight:700;">DATAXPERIENCE</div>
#   <div style="color:#FFFFFF;font-size:15px;margin-top:6px;">Fin del taller 06. Entrega el notebook ejecutado de principio a fin, con una frase de conclusion por ejercicio.</div>
# </div>
